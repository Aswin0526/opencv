# %%
#importing libraries

import os
import cv2
import numpy as np
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
Image('./chessboard.jpg')

# %%
# reading image using opencv

chessboard = cv2.imread('chessboard.jpg',0)

plt.imshow(chessboard)

# matplotlib uses diffrent colormaps
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 5>()
#       1 # reading image using opencv
#       3 chessboard = cv2.imread('chessboard.jpg',0)
# ----> 5 plt.imshow(chessboard)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# ...

# %%
chessboard.shape
# Out:
# (360, 360)

# %%
# specifying color maps

plt.imshow(chessboard,cmap='gray')

# %%
Image('rollsroyce.jpg')

# %%
rollsroyce = cv2.imread('rollsroyce.jpg',1)
print(rollsroyce)
# Out:
# [[[ 54  93  95]
#   [ 48  89  91]
#   [ 40  86  87]
#   ...
#   [160 161 159]
#   [160 161 159]
#   [160 161 159]]
#
#  [[ 63 102 104]
#   [ 54  98  99]
#   [ 53  99 100]
#   ...
#   [160 164 159]
#   [161 162 160]
#   [158 162 157]]
#
#  [[ 97 138 140]
#   [101 147 148]
#   [110 159 157]
#   ...
#   [157 164 157]
#   [156 160 155]
#   [152 159 152]]
#
#  ...
#
#  [[135 136 134]
#   [135 136 134]
#   [135 136 134]
#   ...
#   [143 148 146]
#   [143 148 146]
#   [141 146 144]]
#
#  [[137 138 136]
#   [137 138 136]
#   [137 138 136]
#   ...
#   [146 151 149]
#   [147 152 150]
#   [146 151 149]]
#
#  [[141 142 140]
#   [141 142 140]
#   [141 142 140]
#   ...
#   [147 152 150]
#   [149 154 152]
#   [148 153 151]]]

# %%
plt.imshow(rollsroyce)

# %%
plt.imshow(rollsroyce[:,:,::-1])

# %%
# rollsroyce = rollsroyce[:,:,::-1]

print(rollsroyce)
# Out:
# [[[ 95  93  54]
#   [ 91  89  48]
#   [ 87  86  40]
#   ...
#   [159 161 160]
#   [159 161 160]
#   [159 161 160]]
#
#  [[104 102  63]
#   [ 99  98  54]
#   [100  99  53]
#   ...
#   [159 164 160]
#   [160 162 161]
#   [157 162 158]]
#
#  [[140 138  97]
#   [148 147 101]
#   [157 159 110]
#   ...
#   [157 164 157]
#   [155 160 156]
#   [152 159 152]]
#
#  ...
#
#  [[134 136 135]
#   [134 136 135]
#   [134 136 135]
#   ...
#   [146 148 143]
#   [146 148 143]
#   [144 146 141]]
#
#  [[136 138 137]
#   [136 138 137]
#   [136 138 137]
#   ...
#   [149 151 146]
#   [150 152 147]
#   [149 151 146]]
#
#  [[140 142 141]
#   [140 142 141]
#   [140 142 141]
#   ...
#   [150 152 147]
#   [152 154 149]
#   [151 153 148]]]

# %%
rgb_rolls_royce  = cv2.cvtColor(rollsroyce,cv2.COLOR_BGR2RGB)
# print(rgb_rolls_royce)

# cvtColor not working

# %%
b,g,r = cv2.split(rgb_rolls_royce)

# %%
rgb_rolls_royce = cv2.merge((r,g,b))

plt.imshow(rgb_rolls_royce)

# %%
# saving images

cv2.imwrite('rollsroyce_new.jpg',rgb_rolls_royce)

image = cv2.imread('rollsroyce_new.jpg')

plt.imshow(image)

# %%
print(chessboard)

print(chessboard.shape)
# Out:
# [[255 255 255 ...   0   1   4]
#  [255 255 255 ...   0   1   4]
#  [255 255 255 ...   0   1   4]
#  ...
#  [  0   0   0 ... 255 255 255]
#  [  1   1   1 ... 255 255 255]
#  [  3   3   3 ... 255 255 255]]
# (360, 360)

# %%
plt.imshow(chessboard,cmap='gray')

# %%
plt.imshow(chessboard[0:40,0:40],cmap='gray')

# %%
chessboard_copy = chessboard.copy()
plt.imshow(chessboard_copy,cmap='gray')

# %%
chessboard_copy[0:100,0:100]=77
plt.imshow(chessboard_copy)

# %%
rr = image.copy()

# %%
plt.imshow(rr)

# %%
rr = rr[:,100:600,:]
plt.imshow(rr)

# %%
plt.imshow(cv2.flip(rr,1))
plt.imshow(cv2.flip(rr,0))
plt.imshow(cv2.flip(rr,-1))

# %%
cv2.line(rr,(100,400),(400,400),(255,255,255),thickness=3)
plt.imshow(rr)

# %%
cv2.circle(rr,(300,300),100,(255,255,255),thickness=3)
plt.imshow(rr)

# %%
cv2.rectangle(rgb_rolls_royce,(100,100),(750,500),(255,255,255),thickness=2)
plt.imshow(image)

# %%
cv2.putText(rgb_rolls_royce, "This is Rolls Royce", (100, 100), cv2.FONT_HERSHEY_PLAIN, fontScale=2, color=(255, 255, 255), thickness=5)
plt.imshow(rgb_rolls_royce[:,:,::-1])

# %%
landscape = cv2.imread('landscape.jpg')
landscape = cv2.cvtColor(landscape,cv2.COLOR_BGR2GRAY)
plt.imshow(landscape,cmap='gray')
# Out:
# [[ 6  4  4 ... 12 12 10]
#  [ 3  2  4 ... 12 11 10]
#  [ 5  5  8 ... 10 10  8]
#  ...
#  [ 1  4  1 ...  2  0 14]
#  [ 6  9 14 ...  7 14 10]
#  [31 61 37 ... 13 19  7]]

# %%
matrix = np.ones(landscape.shape,dtype="uint8")*40
print(matrix)

plt.imshow(landscape+matrix,cmap="gray")
# Out:
# [[40 40 40 ... 40 40 40]
#  [40 40 40 ... 40 40 40]
#  [40 40 40 ... 40 40 40]
#  ...
#  [40 40 40 ... 40 40 40]
#  [40 40 40 ... 40 40 40]
#  [40 40 40 ... 40 40 40]]

# %%
plt.imshow(landscape-matrix,cmap="gray")

# %%
chessboard = cv2.imread('./chessboard.jpg',cv2.IMREAD_COLOR)
chessboard = cv2.cvtColor(chessboard,cv2.COLOR_BGR2RGB)
plt.imshow(chessboard)

# %%
matrix = np.ones(chessboard.shape,dtype='int16')
plt.imshow(chessboard-matrix)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(chessboard)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 plt.imshow(chessboard)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2640, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
# ...
